# %%
import json
import datetime
import wget
import os
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from CovidTrackInt import CovidDB

# %%
date = datetime.date(2020,3,5)
end_date = datetime.date(2020,4,10)

# %%
DB = CovidDB(start_date=date, end_date=end_date)

# %%
all_states = []
print(len(DB.jsons))    
print(DB.jsons[0]['state'])

for i in range(len(DB.jsons)):
    if DB.jsons[i]['state'] not in all_states:
        all_states.append(DB.jsons[i]['state'])
print(len(all_states))
# Out:
# 1977
# AZ
# 56

# %%
state_list = ['LA', 'CA', 'GA', 'MD', 'CO']
pop_list = [4.66E6, 39.56E6, 10.52E6, 6.043E6, 5.696E6]
# state_list = ['LA', 'CA', 'NY', 'GA', 'MD', 'CO']
# pop_list = [4.66E6, 39.56E6, 19.54E6, 10.52E6, 6.043E6, 5.696E6]


# state_list = ['LA']
for name in state_list:
    DB.get_state_stats(name)
# Out:
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# ...

# %%
fig, axs = DB.plot_state_totals(state=state_list)

# %%
DB.plot_state_totals(state=state_list, pop_list=pop_list)
# Out:
# (<Figure size 1440x576 with 6 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118e5b490>,
# ...
#        dtype=object))

# %%
fig, axs = DB.plot_state_deltas(state=state_list)
axs[0,0].set_ylim((0,20000))
# Out:
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:114: RuntimeWarning: invalid value encountered in true_divide
#   axs[0, 2].plot(self.stats[item]['dates'][1:], d_positives/d_tests, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:119: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 1].plot(self.stats[item]['dates'][1:], d_deaths/d_positives, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:121: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 2].plot(self.stats[item]['dates'][1:], d_deaths/d_tests, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:114: RuntimeWarning: invalid value encountered in true_divide
#   axs[0, 2].plot(self.stats[item]['dates'][1:], d_positives/d_tests, marker='.', label=item)
# ...

# %%
DB.plot_state_deltas(state=state_list, pop_list=pop_list)
# Out:
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:114: RuntimeWarning: invalid value encountered in true_divide
#   axs[0, 2].plot(self.stats[item]['dates'][1:], d_positives/d_tests, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:119: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 1].plot(self.stats[item]['dates'][1:], d_deaths/d_positives, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:121: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 2].plot(self.stats[item]['dates'][1:], d_deaths/d_tests, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:114: RuntimeWarning: invalid value encountered in true_divide
#   axs[0, 2].plot(self.stats[item]['dates'][1:], d_positives/d_tests, marker='.', label=item)
# ...

# %%
for name in all_states:
    DB.get_state_stats(name)
# Out:
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# something else wrong
# ...

# %%
fig, axs = DB.plot_state_totals(state=all_states)
axs[1,1].set_ylim((0,.06))
axs[0,2].set_ylim((0,.6))
# Out:
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:70: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 1].plot(self.stats[item]['dates'], self.stats[item]['deaths']/self.stats[item]['positives'], label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:70: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 1].plot(self.stats[item]['dates'], self.stats[item]['deaths']/self.stats[item]['positives'], label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:71: RuntimeWarning: invalid value encountered in double_scalars
#   axs[1, 1].text(self.stats[item]['dates'][-1], self.stats[item]['deaths'][-1] / self.stats[item]['positives'][-1],
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:70: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 1].plot(self.stats[item]['dates'], self.stats[item]['deaths']/self.stats[item]['positives'], label=item)
# (0.0, 0.6)
# ...

# %%
fig, axs = DB.plot_state_deltas(state=all_states)
axs[1,0].set_ylim((0,150))
axs[0,1].set_ylim((0,2000))
# Out:
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:114: RuntimeWarning: invalid value encountered in true_divide
#   axs[0, 2].plot(self.stats[item]['dates'][1:], d_positives/d_tests, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:119: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 1].plot(self.stats[item]['dates'][1:], d_deaths/d_positives, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:121: RuntimeWarning: invalid value encountered in true_divide
#   axs[1, 2].plot(self.stats[item]['dates'][1:], d_deaths/d_tests, marker='.', label=item)
# /Users/Clinton/PycharmProjects/CovidTracking/CovidTrackInt.py:114: RuntimeWarning: invalid value encountered in true_divide
#   axs[0, 2].plot(self.stats[item]['dates'][1:], d_positives/d_tests, marker='.', label=item)
# ...
